# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# # We are investigating the predictivity of central bank policy rates and stock market indices as they relate to the price of gold.

# %% [markdown]
# ## Consolidate Central Bank Rates

# %%
# Start by consolidating central bank rate data

# %store -r df_aud
# %store -r df_eur
# %store -r df_gbp
# %store -r df_usd
# %store -r df_yen

# %%
df_aud['date'].min()
# Out:
# Timestamp('1990-01-23 00:00:00')

# %%
df_eur['date'].min()
# Out:
# Timestamp('1999-01-04 00:00:00')

# %%
df_gbp['date'].min()
# Out:
# Timestamp('1975-01-20 00:00:00')

# %%
df_usd['date'].min()
# Out:
# Timestamp('1990-01-01 00:00:00')

# %%
df_yen['date'].min()
# Out:
# Timestamp('2000-01-01 00:00:00')

# %%
# loop through all dataframes and merge via outer join, ensuring the df with the most non-null dates is the left object
df_rates = pd.merge(df_gbp, df_usd, how = 'outer', on = ['date'])
df_rates = pd.merge(df_rates, df_eur, how = 'outer', on = ['date'])
df_rates = pd.merge(df_rates, df_aud, how = 'outer', on = ['date'])
df_rates = pd.merge(df_rates, df_yen, how = 'outer', on = ['date'])

# %%
# drop all values before 2001-01-01 - because we have no yen data prior to then

df_rates = df_rates[df_rates['date']>'1999-12-31']

# %%
df_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7457 entries, 202 to 11272
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              7457 non-null   datetime64[ns]
#  1   gbp_rate          36 non-null     float64
#  2   gbp_rate_lag1     36 non-null     float64
#  3   gbp_rate_dif      36 non-null     float64
#  4   gbp_rate_change%  36 non-null     float64
#  5   usd_rate          7457 non-null   float64
#  6   usd_rate_lag1     7457 non-null   float64
#  7   usd_rate_dif      7457 non-null   float64
#  8   usd_rate_change%  7457 non-null   float64
#  9   eur_rate          44 non-null     float64
#  10  eur_rate_lag1     44 non-null     float64
#  11  eur_rate_dif      44 non-null     float64
#  12  eur_rate_change%  44 non-null     float64
#  13  aud_rate_dif      225 non-null    float64
#  14  aud_rate          225 non-null    float64
#  15  aud_rate_lag1     225 non-null    float64
#  16  aud_rate_change%  225 non-null    float64
#  17  yen_rate          3839 non-null   float64
#  18  yen_rate_lag1     3838 non-null   float64
#  19  yen_rate_dif      3682 non-null   float64
#  20  yen_rate_change%  3556 non-null   float64
# dtypes: datetime64[ns](1), float64(20)
# memory usage: 1.3 MB

# %%
df_rates.rename(columns = {'AUD_rate_tgt%': 'aud_rate'}, inplace = True)

# %%
to_drop = []
for col in df_rates.columns:
    if 'lag' in col:
        to_drop.append(col)

# %%
df_rates.drop(columns = to_drop, inplace = True)

# %%
df_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7457 entries, 202 to 11272
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              7457 non-null   datetime64[ns]
#  1   gbp_rate          36 non-null     float64
#  2   gbp_rate_dif      36 non-null     float64
#  3   gbp_rate_change%  36 non-null     float64
#  4   usd_rate          7457 non-null   float64
#  5   usd_rate_dif      7457 non-null   float64
#  6   usd_rate_change%  7457 non-null   float64
#  7   eur_rate          44 non-null     float64
#  8   eur_rate_dif      44 non-null     float64
#  9   eur_rate_change%  44 non-null     float64
#  10  aud_rate_dif      225 non-null    float64
#  11  aud_rate          225 non-null    float64
#  12  aud_rate_change%  225 non-null    float64
#  13  yen_rate          3839 non-null   float64
#  14  yen_rate_dif      3682 non-null   float64
#  15  yen_rate_change%  3556 non-null   float64
# dtypes: datetime64[ns](1), float64(15)
# memory usage: 990.4 KB

# %%
df_rates = df_rates.sort_values(by = ['date'])

# %%
df_rates = df_rates.set_index('date')

# %%
df_rates.head()
# Out:
#             gbp_rate  gbp_rate_dif  gbp_rate_change%  usd_rate  usd_rate_dif  \
# date
# 2000-01-01       NaN           NaN               NaN       5.5           0.0
# 2000-01-02       NaN           NaN               NaN       5.5           0.0
# 2000-01-03       NaN           NaN               NaN       5.5           0.0
# 2000-01-04       NaN           NaN               NaN       5.5           0.0
# 2000-01-05       NaN           NaN               NaN       5.5           0.0
#
#             usd_rate_change%  eur_rate  eur_rate_dif  eur_rate_change%  \
# date
# 2000-01-01               0.0       NaN           NaN               NaN
# 2000-01-02               0.0       NaN           NaN               NaN
# 2000-01-03               0.0       NaN           NaN               NaN
# 2000-01-04               0.0       NaN           NaN               NaN
# 2000-01-05               0.0       NaN           NaN               NaN
#
#             aud_rate_dif  aud_rate  aud_rate_change%  yen_rate  yen_rate_dif  \
# date
# 2000-01-01           NaN       NaN               NaN       NaN           NaN
# 2000-01-02           NaN       NaN               NaN       NaN           NaN
# 2000-01-03           NaN       NaN               NaN       NaN           NaN
# 2000-01-04           NaN       NaN               NaN       NaN           NaN
# 2000-01-05           NaN       NaN               NaN       NaN           NaN
#
#             yen_rate_change%
# date
# 2000-01-01               NaN
# 2000-01-02               NaN
# 2000-01-03               NaN
# 2000-01-04               NaN
# 2000-01-05               NaN

# %%
# add up to 10 day lag for all rates

for col in df_rates.columns:
    for i in range(1,11):
        df_rates[f'{col}_lag{i}'] = df_rates[col].shift(i)

# %%
df_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7457 entries, 2000-01-01 to 2020-05-31
# Columns: 165 entries, gbp_rate to yen_rate_change%_lag10
# dtypes: float64(165)
# memory usage: 9.4 MB

# %%
for col in df_rates.columns:
    df_rates[col] = df_rates[col].astype('float')

# %%
df_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7457 entries, 2000-01-01 to 2020-05-31
# Columns: 165 entries, gbp_rate to yen_rate_change%_lag10
# dtypes: float64(165)
# memory usage: 9.4 MB

# %%
df_rates.head()
# Out:
#             gbp_rate  gbp_rate_dif  gbp_rate_change%  usd_rate  usd_rate_dif  \
# date
# 2000-01-01       NaN           NaN               NaN       5.5           0.0
# 2000-01-02       NaN           NaN               NaN       5.5           0.0
# 2000-01-03       NaN           NaN               NaN       5.5           0.0
# 2000-01-04       NaN           NaN               NaN       5.5           0.0
# 2000-01-05       NaN           NaN               NaN       5.5           0.0
#
#             usd_rate_change%  eur_rate  eur_rate_dif  eur_rate_change%  \
# date
# 2000-01-01               0.0       NaN           NaN               NaN
# 2000-01-02               0.0       NaN           NaN               NaN
# 2000-01-03               0.0       NaN           NaN               NaN
# 2000-01-04               0.0       NaN           NaN               NaN
# 2000-01-05               0.0       NaN           NaN               NaN
#
#             aud_rate_dif  ...  yen_rate_change%_lag1  yen_rate_change%_lag2  \
# date                      ...
# 2000-01-01           NaN  ...                    NaN                    NaN
# 2000-01-02           NaN  ...                    NaN                    NaN
# 2000-01-03           NaN  ...                    NaN                    NaN
# 2000-01-04           NaN  ...                    NaN                    NaN
# 2000-01-05           NaN  ...                    NaN                    NaN
#
#             yen_rate_change%_lag3  yen_rate_change%_lag4  \
# date
# 2000-01-01                    NaN                    NaN
# 2000-01-02                    NaN                    NaN
# 2000-01-03                    NaN                    NaN
# 2000-01-04                    NaN                    NaN
# 2000-01-05                    NaN                    NaN
#
#             yen_rate_change%_lag5  yen_rate_change%_lag6  \
# date
# 2000-01-01                    NaN                    NaN
# 2000-01-02                    NaN                    NaN
# 2000-01-03                    NaN                    NaN
# 2000-01-04                    NaN                    NaN
# 2000-01-05                    NaN                    NaN
#
#             yen_rate_change%_lag7  yen_rate_change%_lag8  \
# date
# 2000-01-01                    NaN                    NaN
# 2000-01-02                    NaN                    NaN
# 2000-01-03                    NaN                    NaN
# 2000-01-04                    NaN                    NaN
# 2000-01-05                    NaN                    NaN
#
#             yen_rate_change%_lag9  yen_rate_change%_lag10
# date
# 2000-01-01                    NaN                     NaN
# 2000-01-02                    NaN                     NaN
# 2000-01-03                    NaN                     NaN
# 2000-01-04                    NaN                     NaN
# 2000-01-05                    NaN                     NaN
#
# [5 rows x 165 columns]

# %%
# address NaN values

d_non_NaN = dict()
for col in df_rates.columns:
    
    # we can simply fill NaNs in the 'change' columns with zeros, to represent no change
    if 'change' in col:
        df_rates[col].fillna(0, inplace = True)
        
    # otherwise, we'll need to fill NaNs with the most recent non-NaN value
    else:
        
        for idx,val in enumerate(df_rates[col]):
            if pd.isnull(val) == False:
                d_non_NaN[col] = idx
                break
                
            else:
                continue
        
        lst = []
        d = dict()
        for i in df_rates[col][d_non_NaN[col]:]:
            if pd.isnull(i) == False:
                d['last'] = i
            else:
                i = d['last']
            
            lst.append(i)
            
        df_rates[col][d_non_NaN[col]:] = lst

# %%
print(d_non_NaN)
# Out:
# {'gbp_rate': 12, 'gbp_rate_dif': 12, 'usd_rate': 0, 'usd_rate_dif': 0, 'eur_rate': 34, 'eur_rate_dif': 34, 'aud_rate_dif': 32, 'aud_rate': 32, 'yen_rate': 223, 'yen_rate_dif': 224, 'gbp_rate_lag1': 13, 'gbp_rate_lag2': 14, 'gbp_rate_lag3': 15, 'gbp_rate_lag4': 16, 'gbp_rate_lag5': 17, 'gbp_rate_lag6': 18, 'gbp_rate_lag7': 19, 'gbp_rate_lag8': 20, 'gbp_rate_lag9': 21, 'gbp_rate_lag10': 22, 'gbp_rate_dif_lag1': 13, 'gbp_rate_dif_lag2': 14, 'gbp_rate_dif_lag3': 15, 'gbp_rate_dif_lag4': 16, 'gbp_rate_dif_lag5': 17, 'gbp_rate_dif_lag6': 18, 'gbp_rate_dif_lag7': 19, 'gbp_rate_dif_lag8': 20, 'gbp_rate_dif_lag9': 21, 'gbp_rate_dif_lag10': 22, 'usd_rate_lag1': 1, 'usd_rate_lag2': 2, 'usd_rate_lag3': 3, 'usd_rate_lag4': 4, 'usd_rate_lag5': 5, 'usd_rate_lag6': 6, 'usd_rate_lag7': 7, 'usd_rate_lag8': 8, 'usd_rate_lag9': 9, 'usd_rate_lag10': 10, 'usd_rate_dif_lag1': 1, 'usd_rate_dif_lag2': 2, 'usd_rate_dif_lag3': 3, 'usd_rate_dif_lag4': 4, 'usd_rate_dif_lag5': 5, 'usd_rate_dif_lag6': 6, 'usd_rate_dif_lag7': 7, 'usd_rate_dif_lag8': 8, 'usd_rate_dif_lag9': 9, 'usd_rate_dif_lag10': 10, 'eur_rate_lag1': 35, 'eur_rate_lag2': 36, 'eur_rate_lag3': 37, 'eur_rate_lag4': 38, 'eur_rate_lag5': 39, 'eur_rate_lag6': 40, 'eur_rate_lag7': 41, 'eur_rate_lag8': 42, 'eur_rate_lag9': 43, 'eur_rate_lag10': 44, 'eur_rate_dif_lag1': 35, 'eur_rate_dif_lag2': 36, 'eur_rate_dif_lag3': 37, 'eur_rate_dif_lag4': 38, 'eur_rate_dif_lag5': 39, 'eur_rate_dif_lag6': 40, 'eur_rate_dif_lag7': 41, 'eur_rate_dif_lag8': 42, 'eur_rate_dif_lag9': 43, 'eur_rate_dif_lag10': 44, 'aud_rate_dif_lag1': 33, 'aud_rate_dif_lag2': 34, 'aud_rate_dif_lag3': 35, 'aud_rate_dif_lag4': 36, 'aud_rate_dif_lag5': 37, 'aud_rate_dif_lag6': 38, 'aud_rate_dif_lag7': 39, 'aud_rate_dif_lag8': 40, 'aud_rate_dif_lag9': 41, 'aud_rate_dif_lag10': 42, 'aud_rate_lag1': 33, 'aud_rate_lag2': 34, 'aud_rate_lag3': 35, 'aud_rate_lag4': 36, 'aud_rate_lag5': 37, 'aud_rate_lag6': 38, 'aud_rate_lag7': 39, 'aud_rate_lag8': 40, 'aud_rate_lag9': 41, 'aud_rate_lag10': 42, 'yen_rate_lag1': 224, 'yen_rate_lag2': 225, 'yen_rate_lag3': 226, 'yen_rate_lag4': 227, 'yen_rate_lag5': 228, 'yen_rate_lag6': 229, 'yen_rate_lag7': 230, 'yen_rate_lag8': 231, 'yen_rate_lag9': 232, 'yen_rate_lag10': 233, 'yen_rate_dif_lag1': 225, 'yen_rate_dif_lag2': 226, 'yen_rate_dif_lag3': 227, 'yen_rate_dif_lag4': 228, 'yen_rate_dif_lag5': 229, 'yen_rate_dif_lag6': 230, 'yen_rate_dif_lag7': 231, 'yen_rate_dif_lag8': 232, 'yen_rate_dif_lag9': 233, 'yen_rate_dif_lag10': 234}

# %%
df_rates['gbp_rate'][33:36]
# Out:
# date
# 2000-02-03    5.75
# 2000-02-04    5.75
# 2000-02-05    5.75
# Name: gbp_rate, dtype: float64

# %%
df_rates.head()
# Out:
#             gbp_rate  gbp_rate_dif  gbp_rate_change%  usd_rate  usd_rate_dif  \
# date
# 2000-01-01       NaN           NaN               0.0       5.5           0.0
# 2000-01-02       NaN           NaN               0.0       5.5           0.0
# 2000-01-03       NaN           NaN               0.0       5.5           0.0
# 2000-01-04       NaN           NaN               0.0       5.5           0.0
# 2000-01-05       NaN           NaN               0.0       5.5           0.0
#
#             usd_rate_change%  eur_rate  eur_rate_dif  eur_rate_change%  \
# date
# 2000-01-01               0.0       NaN           NaN               0.0
# 2000-01-02               0.0       NaN           NaN               0.0
# 2000-01-03               0.0       NaN           NaN               0.0
# 2000-01-04               0.0       NaN           NaN               0.0
# 2000-01-05               0.0       NaN           NaN               0.0
#
#             aud_rate_dif  ...  yen_rate_change%_lag1  yen_rate_change%_lag2  \
# date                      ...
# 2000-01-01           NaN  ...                    0.0                    0.0
# 2000-01-02           NaN  ...                    0.0                    0.0
# 2000-01-03           NaN  ...                    0.0                    0.0
# 2000-01-04           NaN  ...                    0.0                    0.0
# 2000-01-05           NaN  ...                    0.0                    0.0
#
#             yen_rate_change%_lag3  yen_rate_change%_lag4  \
# date
# 2000-01-01                    0.0                    0.0
# 2000-01-02                    0.0                    0.0
# 2000-01-03                    0.0                    0.0
# 2000-01-04                    0.0                    0.0
# 2000-01-05                    0.0                    0.0
#
#             yen_rate_change%_lag5  yen_rate_change%_lag6  \
# date
# 2000-01-01                    0.0                    0.0
# 2000-01-02                    0.0                    0.0
# 2000-01-03                    0.0                    0.0
# 2000-01-04                    0.0                    0.0
# 2000-01-05                    0.0                    0.0
#
#             yen_rate_change%_lag7  yen_rate_change%_lag8  \
# date
# 2000-01-01                    0.0                    0.0
# 2000-01-02                    0.0                    0.0
# 2000-01-03                    0.0                    0.0
# 2000-01-04                    0.0                    0.0
# 2000-01-05                    0.0                    0.0
#
#             yen_rate_change%_lag9  yen_rate_change%_lag10
# date
# 2000-01-01                    0.0                     0.0
# 2000-01-02                    0.0                     0.0
# 2000-01-03                    0.0                     0.0
# 2000-01-04                    0.0                     0.0
# 2000-01-05                    0.0                     0.0
#
# [5 rows x 165 columns]

# %%
# %store df_rates
# Out:
# Stored 'df_rates' (DataFrame)

# %% [markdown]
# ## Consolidate stock indices

# %%
# %store -r df_hsi
# %store -r df_sse
# %store -r df_jeg
# %store -r df_nasdaq
# %store -r df_nyse

# %%
df_hsi['date'].min()
# Out:
# Timestamp('2000-01-03 00:00:00')

# %%
df_sse['date'].min()
# Out:
# Timestamp('1997-07-02 00:00:00')

# %%
df_jeg['date'].min()
# Out:
# Timestamp('2008-09-05 00:00:00')

# %%
df_nasdaq['date'].min()
# Out:
# Timestamp('2000-01-03 00:00:00')

# %%
df_nyse['date'].min()
# Out:
# Timestamp('2000-01-03 00:00:00')

# %%
# loop through all dataframes and merge via outer join, ensuring the df with the most non-null dates is the left object
df_stock = pd.merge(df_sse, df_hsi, how = 'outer', on = ['date'])
df_stock = pd.merge(df_stock, df_nyse, how = 'outer', on = ['date'])
df_stock = pd.merge(df_stock, df_nasdaq, how = 'outer', on = ['date'])
df_stock = pd.merge(df_stock, df_jeg, how = 'outer', on = ['date'])

# %%
# drop all values before 2008-09-05 - because we have no JEG data prior to then

df_stock = df_stock[df_stock['date']>'2008-09-04']

# %%
df_stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3051 entries, 2871 to 5963
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               3051 non-null   datetime64[ns]
#  1   sse_close          2845 non-null   float64
#  2   sse_close_lag1     2845 non-null   float64
#  3   sse_change%        2844 non-null   float64
#  4   sse_dif            2844 non-null   float64
#  5   hsi_close          2881 non-null   float64
#  6   hsi_close_lag1     2881 non-null   float64
#  7   hsi_change%        2868 non-null   float64
#  8   hsi_dif            2868 non-null   float64
#  9   nyse_close         2950 non-null   float64
#  10  nyse_close_lag1    2950 non-null   float64
#  11  nyse_change%       2950 non-null   float64
#  12  nyse_dif           2950 non-null   float64
#  13  nasdaq_close       2950 non-null   float64
#  14  nasdaq_close_lag1  2950 non-null   float64
#  15  nasdaq_change%     2950 non-null   float64
#  16  nasdaq_dif         2950 non-null   float64
#  17  jeg_close          2869 non-null   float64
#  18  jeg_close_lag1     2868 non-null   float64
#  19  jeg_change%        2856 non-null   float64
#  20  jeg_dif            2856 non-null   float64
# dtypes: datetime64[ns](1), float64(20)
# memory usage: 524.4 KB

# %%
to_drop = []
for col in df_stock.columns:
    if 'lag' in col:
        to_drop.append(col)

# %%
df_stock.drop(columns = to_drop, inplace = True)

# %%
df_stock = df_stock.sort_values(by = ['date'])

# %%
df_stock = df_stock.set_index('date')

# %%
df_stock.head()
# Out:
#               sse_close  sse_change%    sse_dif     hsi_close  hsi_change%  \
# date
# 2008-09-05  2202.446045    -3.291670 -74.964844  19933.279297    -2.237434
# 2008-09-08  2143.420898    -2.679982 -59.025147  20794.269531     4.319361
# 2008-09-09  2145.779053     0.110018   2.358155  20491.109375    -1.457902
# 2008-09-10  2150.759033     0.232083   4.979980  19999.779297    -2.397772
# 2008-09-11  2078.980957    -3.337337 -71.778076  19388.720703    -3.055327
#
#                hsi_dif   nyse_close  nyse_change%    nyse_dif  nasdaq_close  \
# date
# 2008-09-05 -456.201172  8033.759766      0.318544   25.509766   2255.879883
# 2008-09-08  860.990234  8168.620117      1.678670  134.860351   2269.760010
# 2008-09-09 -303.160156  7871.149902     -3.641621 -297.470215   2209.810059
# 2008-09-10 -491.330078  7957.259766      1.093993   86.109864   2228.699951
# 2008-09-11 -611.058594  8011.250000      0.678503   53.990234   2258.219971
#
#             nasdaq_change%  nasdaq_dif   jeg_close  jeg_change%    jeg_dif
# date
# 2008-09-05       -0.139889   -3.160156  335.000000          NaN        NaN
# 2008-09-08        0.615287   13.880127  343.000000     2.388060   8.000000
# 2008-09-09       -2.641246  -59.949951  337.864990    -1.497087  -5.135010
# 2008-09-10        0.854820   18.889892  319.382996    -5.470231 -18.481994
# 2008-09-11        1.324540   29.520020  290.799988    -8.949446 -28.583008

# %%
df_stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3051 entries, 2008-09-05 to 2020-05-27
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sse_close       2845 non-null   float64
#  1   sse_change%     2844 non-null   float64
#  2   sse_dif         2844 non-null   float64
#  3   hsi_close       2881 non-null   float64
#  4   hsi_change%     2868 non-null   float64
#  5   hsi_dif         2868 non-null   float64
#  6   nyse_close      2950 non-null   float64
#  7   nyse_change%    2950 non-null   float64
#  8   nyse_dif        2950 non-null   float64
#  9   nasdaq_close    2950 non-null   float64
#  10  nasdaq_change%  2950 non-null   float64
#  11  nasdaq_dif      2950 non-null   float64
#  12  jeg_close       2869 non-null   float64
#  13  jeg_change%     2856 non-null   float64
#  14  jeg_dif         2856 non-null   float64
# dtypes: float64(15)
# memory usage: 381.4 KB

# %%
# add up to 10 day lag for all stock indices and changes
for col in df_stock.columns:
    for i in range(1,11):
        df_stock[f'{col}_lag{i}'] = df_stock[col].shift(i)

# %%
df_stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3051 entries, 2008-09-05 to 2020-05-27
# Columns: 165 entries, sse_close to jeg_dif_lag10
# dtypes: float64(165)
# memory usage: 3.9 MB

# %%
# address NaN values

d_non_NaN = dict()
for col in df_stock.columns:
    
    # we can simply fill NaNs in the 'change' columns with zeros, to represent no change
    if 'change' in col:
        df_stock[col].fillna(0, inplace = True)
        
    # otherwise, we'll need to fill NaNs with the most recent non-NaN value
    else:
        
        for idx,val in enumerate(df_stock[col]):
            if pd.isnull(val) == False:
                d_non_NaN[col] = idx
                break
                
            else:
                continue
        
        lst = []
        d = dict()
        for i in df_stock[col][d_non_NaN[col]:]:
            if pd.isnull(i) == False:
                d['last'] = i
            else:
                i = d['last']
            
            lst.append(i)
            
        df_stock[col][d_non_NaN[col]:] = lst

# %%
print(d_non_NaN)
# Out:
# {'sse_close': 0, 'sse_dif': 0, 'hsi_close': 0, 'hsi_dif': 0, 'nyse_close': 0, 'nyse_dif': 0, 'nasdaq_close': 0, 'nasdaq_dif': 0, 'jeg_close': 0, 'jeg_dif': 1, 'sse_close_lag1': 1, 'sse_close_lag2': 2, 'sse_close_lag3': 3, 'sse_close_lag4': 4, 'sse_close_lag5': 5, 'sse_close_lag6': 6, 'sse_close_lag7': 7, 'sse_close_lag8': 8, 'sse_close_lag9': 9, 'sse_close_lag10': 10, 'sse_dif_lag1': 1, 'sse_dif_lag2': 2, 'sse_dif_lag3': 3, 'sse_dif_lag4': 4, 'sse_dif_lag5': 5, 'sse_dif_lag6': 6, 'sse_dif_lag7': 7, 'sse_dif_lag8': 8, 'sse_dif_lag9': 9, 'sse_dif_lag10': 10, 'hsi_close_lag1': 1, 'hsi_close_lag2': 2, 'hsi_close_lag3': 3, 'hsi_close_lag4': 4, 'hsi_close_lag5': 5, 'hsi_close_lag6': 6, 'hsi_close_lag7': 7, 'hsi_close_lag8': 8, 'hsi_close_lag9': 9, 'hsi_close_lag10': 10, 'hsi_dif_lag1': 1, 'hsi_dif_lag2': 2, 'hsi_dif_lag3': 3, 'hsi_dif_lag4': 4, 'hsi_dif_lag5': 5, 'hsi_dif_lag6': 6, 'hsi_dif_lag7': 7, 'hsi_dif_lag8': 8, 'hsi_dif_lag9': 9, 'hsi_dif_lag10': 10, 'nyse_close_lag1': 1, 'nyse_close_lag2': 2, 'nyse_close_lag3': 3, 'nyse_close_lag4': 4, 'nyse_close_lag5': 5, 'nyse_close_lag6': 6, 'nyse_close_lag7': 7, 'nyse_close_lag8': 8, 'nyse_close_lag9': 9, 'nyse_close_lag10': 10, 'nyse_dif_lag1': 1, 'nyse_dif_lag2': 2, 'nyse_dif_lag3': 3, 'nyse_dif_lag4': 4, 'nyse_dif_lag5': 5, 'nyse_dif_lag6': 6, 'nyse_dif_lag7': 7, 'nyse_dif_lag8': 8, 'nyse_dif_lag9': 9, 'nyse_dif_lag10': 10, 'nasdaq_close_lag1': 1, 'nasdaq_close_lag2': 2, 'nasdaq_close_lag3': 3, 'nasdaq_close_lag4': 4, 'nasdaq_close_lag5': 5, 'nasdaq_close_lag6': 6, 'nasdaq_close_lag7': 7, 'nasdaq_close_lag8': 8, 'nasdaq_close_lag9': 9, 'nasdaq_close_lag10': 10, 'nasdaq_dif_lag1': 1, 'nasdaq_dif_lag2': 2, 'nasdaq_dif_lag3': 3, 'nasdaq_dif_lag4': 4, 'nasdaq_dif_lag5': 5, 'nasdaq_dif_lag6': 6, 'nasdaq_dif_lag7': 7, 'nasdaq_dif_lag8': 8, 'nasdaq_dif_lag9': 9, 'nasdaq_dif_lag10': 10, 'jeg_close_lag1': 1, 'jeg_close_lag2': 2, 'jeg_close_lag3': 3, 'jeg_close_lag4': 4, 'jeg_close_lag5': 5, 'jeg_close_lag6': 6, 'jeg_close_lag7': 7, 'jeg_close_lag8': 8, 'jeg_close_lag9': 9, 'jeg_close_lag10': 10, 'jeg_dif_lag1': 2, 'jeg_dif_lag2': 3, 'jeg_dif_lag3': 4, 'jeg_dif_lag4': 5, 'jeg_dif_lag5': 6, 'jeg_dif_lag6': 7, 'jeg_dif_lag7': 8, 'jeg_dif_lag8': 9, 'jeg_dif_lag9': 10, 'jeg_dif_lag10': 11}

# %%
df_stock['jeg_close_lag10'][9:14]
# Out:
# date
# 2008-09-18           NaN
# 2008-09-19    335.000000
# 2008-09-22    343.000000
# 2008-09-23    337.864990
# 2008-09-24    319.382996
# Name: jeg_close_lag10, dtype: float64

# %%
df_stock.head()
# Out:
#               sse_close  sse_change%    sse_dif     hsi_close  hsi_change%  \
# date
# 2008-09-05  2202.446045    -3.291670 -74.964844  19933.279297    -2.237434
# 2008-09-08  2143.420898    -2.679982 -59.025147  20794.269531     4.319361
# 2008-09-09  2145.779053     0.110018   2.358155  20491.109375    -1.457902
# 2008-09-10  2150.759033     0.232083   4.979980  19999.779297    -2.397772
# 2008-09-11  2078.980957    -3.337337 -71.778076  19388.720703    -3.055327
#
#                hsi_dif   nyse_close  nyse_change%    nyse_dif  nasdaq_close  \
# date
# 2008-09-05 -456.201172  8033.759766      0.318544   25.509766   2255.879883
# 2008-09-08  860.990234  8168.620117      1.678670  134.860351   2269.760010
# 2008-09-09 -303.160156  7871.149902     -3.641621 -297.470215   2209.810059
# 2008-09-10 -491.330078  7957.259766      1.093993   86.109864   2228.699951
# 2008-09-11 -611.058594  8011.250000      0.678503   53.990234   2258.219971
#
#             ...  jeg_dif_lag1  jeg_dif_lag2  jeg_dif_lag3  jeg_dif_lag4  \
# date        ...
# 2008-09-05  ...           NaN           NaN           NaN           NaN
# 2008-09-08  ...           NaN           NaN           NaN           NaN
# 2008-09-09  ...      8.000000           NaN           NaN           NaN
# 2008-09-10  ...     -5.135010       8.00000           NaN           NaN
# 2008-09-11  ...    -18.481994      -5.13501           8.0           NaN
#
#             jeg_dif_lag5  jeg_dif_lag6  jeg_dif_lag7  jeg_dif_lag8  \
# date
# 2008-09-05           NaN           NaN           NaN           NaN
# 2008-09-08           NaN           NaN           NaN           NaN
# 2008-09-09           NaN           NaN           NaN           NaN
# 2008-09-10           NaN           NaN           NaN           NaN
# 2008-09-11           NaN           NaN           NaN           NaN
#
#             jeg_dif_lag9  jeg_dif_lag10
# date
# 2008-09-05           NaN            NaN
# 2008-09-08           NaN            NaN
# 2008-09-09           NaN            NaN
# 2008-09-10           NaN            NaN
# 2008-09-11           NaN            NaN
#
# [5 rows x 165 columns]

# %%
# %store df_stock
# Out:
# Stored 'df_stock' (DataFrame)

# %%
df_feat = pd.merge(df_rates, df_stock, how = 'inner', on = ['date'])

# %%
df_feat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3051 entries, 2008-09-05 to 2020-05-27
# Columns: 330 entries, gbp_rate to jeg_dif_lag10
# dtypes: float64(330)
# memory usage: 7.7 MB

# %%
df_feat.head()
# Out:
#             gbp_rate  gbp_rate_dif  gbp_rate_change%  usd_rate  usd_rate_dif  \
# date
# 2008-09-05       5.0         -0.25               0.0       2.0           0.0
# 2008-09-08       5.0         -0.25               0.0       2.0           0.0
# 2008-09-09       5.0         -0.25               0.0       2.0           0.0
# 2008-09-10       5.0         -0.25               0.0       2.0           0.0
# 2008-09-11       5.0         -0.25               0.0       2.0           0.0
#
#             usd_rate_change%  eur_rate  eur_rate_dif  eur_rate_change%  \
# date
# 2008-09-05               0.0      3.25          0.25               0.0
# 2008-09-08               0.0      3.25          0.25               0.0
# 2008-09-09               0.0      3.25          0.25               0.0
# 2008-09-10               0.0      3.25          0.25               0.0
# 2008-09-11               0.0      3.25          0.25               0.0
#
#             aud_rate_dif  ...  jeg_dif_lag1  jeg_dif_lag2  jeg_dif_lag3  \
# date                      ...
# 2008-09-05         -0.25  ...           NaN           NaN           NaN
# 2008-09-08         -0.25  ...           NaN           NaN           NaN
# 2008-09-09         -0.25  ...      8.000000           NaN           NaN
# 2008-09-10         -0.25  ...     -5.135010       8.00000           NaN
# 2008-09-11         -0.25  ...    -18.481994      -5.13501           8.0
#
#             jeg_dif_lag4  jeg_dif_lag5  jeg_dif_lag6  jeg_dif_lag7  \
# date
# 2008-09-05           NaN           NaN           NaN           NaN
# 2008-09-08           NaN           NaN           NaN           NaN
# 2008-09-09           NaN           NaN           NaN           NaN
# 2008-09-10           NaN           NaN           NaN           NaN
# 2008-09-11           NaN           NaN           NaN           NaN
#
#             jeg_dif_lag8  jeg_dif_lag9  jeg_dif_lag10
# date
# 2008-09-05           NaN           NaN            NaN
# 2008-09-08           NaN           NaN            NaN
# 2008-09-09           NaN           NaN            NaN
# 2008-09-10           NaN           NaN            NaN
# 2008-09-11           NaN           NaN            NaN
#
# [5 rows x 330 columns]

# %%
# %store df_feat
# Out:
# Stored 'df_feat' (DataFrame)

# %% [markdown]
# ## Merge in gold data and create final Xy dataframe for model

# %%
# %store -r df_gold

# %%
df_gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7845 entries, 261 to 8311
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          7845 non-null   datetime64[ns]
#  1   gold          7845 non-null   float64
#  2   gold_lag1     7844 non-null   float64
#  3   gold_change%  7844 non-null   float64
#  4   gold_dif      7844 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 367.7 KB

# %%
df_gold = df_gold.sort_values(by = ['date'])
df_gold = df_gold.set_index('date')

# %%
to_drop = []
for col in df_gold.columns:
    if 'lag' in col:
        to_drop.append(col)

# %%
df_gold.drop(columns = to_drop, inplace = True)

# %%
# add up to 10 day lag for all gold prices and daily changes
for col in df_gold.columns:
    for i in range(1,11):
        df_gold[f'{col}_lag{i}'] = df_gold[col].shift(i)

# %%
df_gold.head()
# Out:
#               gold  gold_change%  gold_dif  gold_lag1  gold_lag2  gold_lag3  \
# date
# 1990-01-03  394.50           NaN       NaN        NaN        NaN        NaN
# 1990-01-04  398.80      1.089987      4.30     394.50        NaN        NaN
# 1990-01-05  406.10      1.830491      7.30     398.80      394.5        NaN
# 1990-01-08  401.85     -1.046540     -4.25     406.10      398.8      394.5
# 1990-01-09  405.50      0.908299      3.65     401.85      406.1      398.8
#
#             gold_lag4  gold_lag5  gold_lag6  gold_lag7  ...  gold_dif_lag1  \
# date                                                    ...
# 1990-01-03        NaN        NaN        NaN        NaN  ...            NaN
# 1990-01-04        NaN        NaN        NaN        NaN  ...            NaN
# 1990-01-05        NaN        NaN        NaN        NaN  ...           4.30
# 1990-01-08        NaN        NaN        NaN        NaN  ...           7.30
# 1990-01-09      394.5        NaN        NaN        NaN  ...          -4.25
#
#             gold_dif_lag2  gold_dif_lag3  gold_dif_lag4  gold_dif_lag5  \
# date
# 1990-01-03            NaN            NaN            NaN            NaN
# 1990-01-04            NaN            NaN            NaN            NaN
# 1990-01-05            NaN            NaN            NaN            NaN
# 1990-01-08            4.3            NaN            NaN            NaN
# 1990-01-09            7.3            4.3            NaN            NaN
#
#             gold_dif_lag6  gold_dif_lag7  gold_dif_lag8  gold_dif_lag9  \
# date
# 1990-01-03            NaN            NaN            NaN            NaN
# 1990-01-04            NaN            NaN            NaN            NaN
# 1990-01-05            NaN            NaN            NaN            NaN
# 1990-01-08            NaN            NaN            NaN            NaN
# 1990-01-09            NaN            NaN            NaN            NaN
#
#             gold_dif_lag10
# date
# 1990-01-03             NaN
# 1990-01-04             NaN
# 1990-01-05             NaN
# 1990-01-08             NaN
# 1990-01-09             NaN
#
# [5 rows x 33 columns]

# %%
df_Xy = pd.merge(df_feat, df_gold, how = 'inner', on = ['date'])

# %%
df_Xy.head()
# Out:
#             gbp_rate  gbp_rate_dif  gbp_rate_change%  usd_rate  usd_rate_dif  \
# date
# 2008-09-05       5.0         -0.25               0.0       2.0           0.0
# 2008-09-08       5.0         -0.25               0.0       2.0           0.0
# 2008-09-09       5.0         -0.25               0.0       2.0           0.0
# 2008-09-10       5.0         -0.25               0.0       2.0           0.0
# 2008-09-11       5.0         -0.25               0.0       2.0           0.0
#
#             usd_rate_change%  eur_rate  eur_rate_dif  eur_rate_change%  \
# date
# 2008-09-05               0.0      3.25          0.25               0.0
# 2008-09-08               0.0      3.25          0.25               0.0
# 2008-09-09               0.0      3.25          0.25               0.0
# 2008-09-10               0.0      3.25          0.25               0.0
# 2008-09-11               0.0      3.25          0.25               0.0
#
#             aud_rate_dif  ...  gold_dif_lag1  gold_dif_lag2  gold_dif_lag3  \
# date                      ...
# 2008-09-05         -0.25  ...          -1.82          -5.75          -9.17
# 2008-09-08         -0.25  ...           0.82          -1.82          -5.75
# 2008-09-09         -0.25  ...          -0.51           0.82          -1.82
# 2008-09-10         -0.25  ...         -15.94          -0.51           0.82
# 2008-09-11         -0.25  ...         -23.35         -15.94          -0.51
#
#             gold_dif_lag4  gold_dif_lag5  gold_dif_lag6  gold_dif_lag7  \
# date
# 2008-09-05         -13.33          -0.81           4.96           1.80
# 2008-09-08          -9.17         -13.33          -0.81           4.96
# 2008-09-09          -5.75          -9.17         -13.33          -0.81
# 2008-09-10          -1.82          -5.75          -9.17         -13.33
# 2008-09-11           0.82          -1.82          -5.75          -9.17
#
#             gold_dif_lag8  gold_dif_lag9  gold_dif_lag10
# date
# 2008-09-05           3.52          -6.65           -6.77
# 2008-09-08           1.80           3.52           -6.65
# 2008-09-09           4.96           1.80            3.52
# 2008-09-10          -0.81           4.96            1.80
# 2008-09-11         -13.33          -0.81            4.96
#
# [5 rows x 363 columns]

# %%
df_Xy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3032 entries, 2008-09-05 to 2020-05-27
# Columns: 363 entries, gbp_rate to gold_dif_lag10
# dtypes: float64(363)
# memory usage: 8.4 MB

# %%
# %store df_Xy
# Out:
# Stored 'df_Xy' (DataFrame)

# %%
df_Xy.to_csv('dfXy.csv')
